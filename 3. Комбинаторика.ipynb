# %%
from math import factorial

# %% [markdown]
# # Комбинаторика

# %% [markdown]
# ![Screenshot%202020-11-07%20at%2022.51.21-2.png](attachment:Screenshot%202020-11-07%20at%2022.51.21-2.png)

# %% [markdown]
# ![Screenshot%202023-03-27%20at%2000.11.54.png](attachment:Screenshot%202023-03-27%20at%2000.11.54.png)

# %% [markdown]
# ## 1
# Производитель шин хочет провести испытания четырех различных типов шин на трех различных типах дорог и на пяти различных скоростях. Сколько необходимо провести тестов?

# %%
4*3*5
# Out:
# 60

# %% [markdown]
# ## 2
# Школа вручает пять наград по пяти предметам в классе из 30 учеников, причем каждый ученик может получить только одну награду. Сколькими способами можно вручить награды ученикам?

# %%
factorial(30) / factorial(30 - 5)
# Out:
# 17100720.0

# %% [markdown]
# ## 3
# Сколькими способами из класса, в котором учатся 30 школьников, можно выбрать капитана команды для математических боев и его заместителя?

# %%
factorial(30) / factorial(30 - 2)
# Out:
# 870.0

# %% [markdown]
# ## 4
# Сколькими способами из класса, в котором учатся 30 школьников, можно выбрать двоих для участия в математической олимпиаде?

# %%
factorial(30) / (factorial(30-2) * factorial(2))
# Out:
# 435.0

# %% [markdown]
# ## 5
# Сколькими способами можно построить пятерых человек в шеренгу?

# %%
factorial(5)
# Out:
# 120

# %% [markdown]
# ## 6
# Сколькими способами 5 человек могут встать в круг, чтобы водить хоровод (важно только их взаимное расположение)?

# %%
factorial(4)
# Out:
# 24

# %% [markdown]
# ## 7
# Сколькими способами 6 различных шаров можно случайно раскидать по трем различным ящикам?

# %%
3**6
# Out:
# 729

# %% [markdown]
# ## 8
# Сколькими способами 6 одинаковых шаров можно случайно раскидать по трем различным ящикам?

# %%
factorial(8) / (factorial(6) * factorial(2))
# Out:
# 28.0

# %% [markdown]
# ## 9
# Подбрасывается 10 правильных монет. Найдите вероятность того, что на всех монетах выпадет орел.

# %%
1/(2**10)
# Out:
# 0.0009765625

# %% [markdown]
# ## 10
# Пять бизнесменов пришли на встречу. Сколько будет сделано рукопожатий, если каждый бизнесмен пожимает руку всем остальным?

# %%
factorial(5) / (factorial(3) * factorial(2))
# Out:
# 10.0

# %% [markdown]
# ## 11
# У Артема 12 друзей, 7 из них он приглашает на вечеринку.
# a) Сколько существует вариантов пригласить гостей, если Петя и Тимур не хотят быть на вечеринке вместе.

# %%
factorial(12) / (factorial(7) * factorial(5)) - factorial(10) / (factorial(5) * factorial(5))
# Out:
# 540.0

# %% [markdown]
# ## 12
# У Артема 12 друзей, 7 из них он приглашает на вечеринку.
# b) Сколько существует вариантов пригласить гостей, если Петя и Тимур настаивают на том, что либо они оба придут, либо не придет никто из них.

# %%
factorial(10) / (factorial(7) * factorial(3))
# Out:
# 120.0

# %%
factorial(10) / (factorial(5) * factorial(5))
# Out:
# 252.0

# %%
120+252
# Out:
# 372

# %% [markdown]
# ## 13
# Шесть студентов, три мальчика и три девочки, выстраиваются случайным образом в ряд для общей фотографии. Какова вероятность того, что мальчики будут чередоваться с девочками?

# %%
72 / factorial(6)
# Out:
# 0.1

# %% [markdown]
# ## 14
# Сколькими способами можно поставить четыре различные ладьи на шахматной доске так, чтобы ни одна ладья не била другую?

# %%
64*49*36*25
# Out:
# 2822400

# %% [markdown]
# ## 15
# Абонент забыл последние две цифры пин-кода своей сим-карты, однако помнит, что они различны. Он вводит две цифры наудачу. Какова вероятность того, что введенный пин-код окажется правильным?

# %%
factorial(10) / factorial(10 - 2)
# Out:
# 90.0

# %%
1 / 90
# Out:
# 0.011111111111111112

# %% [markdown]
# ## 16
# (Контроль качества) 50 деталей, среди которых 4 дефектных, отправляются к месту сборки. Отдел контроля качества выбирает 10 деталей наугад для проверки и бракует всю партию, если, по крайней мере, 1 деталь оказались дефектной. Какова вероятность того, что эта партия пройдет проверку?

# %%
factorial(50) / (factorial(40) * factorial(10))
# Out:
# 10272278170.0

# %%
factorial(46) / (factorial(36) * factorial(10))
# Out:
# 4076350421.0

# %%
4076350421 / 10272278170
# Out:
# 0.39683022145028224
