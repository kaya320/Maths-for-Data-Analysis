# %%
from math import factorial
from scipy.stats import poisson
from scipy.stats import binom

# %% [markdown]
# ![Screenshot%202020-09-10%20at%2002.47.22.png](attachment:Screenshot%202020-09-10%20at%2002.47.22.png)

# %% [markdown]
# ![Screenshot%202020-11-19%20at%2001.46.32.png](attachment:Screenshot%202020-11-19%20at%2001.46.32.png)

# %% [markdown]
# ![Screenshot%202023-09-28%20at%2023.01.16.png](attachment:Screenshot%202023-09-28%20at%2023.01.16.png)

# %% [markdown]
# ## 1
# 10 раз подбрасываем правильную кость. Найдите вероятность того, что ровно два раза выпало число очков, большее или равное пяти.

# %%
binom.pmf(2, 10, 1/3)
# Out:
# 0.19509221155311718

# %%
factorial(10) / (factorial(10-2) * factorial(2)) * (2/6)**2 * (4/6)**(10-2)
# Out:
# 0.1950922115531168

# %% [markdown]
# ## 2
# Страховая компания страхует 3000 человек, с каждым из которых в течение года может случиться страховой случай с вероятностью
# 1/1000. Используйте приближение Пуассона для вычисления вероятности того, что произойдет не более 2 таких случаев за год. Принять число e=2.718282

# %%
poisson.cdf(2, 3000 * 0.001)
# Out:
# 0.42319008112684364

# %%
poisson.cdf(2, 1000 * 0.001)
